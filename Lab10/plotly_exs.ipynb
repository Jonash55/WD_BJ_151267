# %%
import pandas as pd
import plotly.express as px

from plotly.offline import init_notebook_mode

# %% [markdown]
# ### Wykorzystując zbiór danych zamówienia, wyświetl strukturę wartości zamówień dla sprzedawców z Polski używając jednego z wykresów z rozdziału https://plotly.com/python/funnel-charts/ w dokumentacji biblioteki plotly.

# %%
init_notebook_mode(connected=True)

df_zamowienia = pd.read_csv('data/zamowienia.csv', sep=';')
df_zamowienia
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16         10248   440.00
# 1    Polska   Sowiński      2003-07-10         10249  1863.40
# 2    Niemcy    Peacock      2003-07-12         10250  1552.60
# 3    Niemcy  Leverling      2003-07-15         10251   654.06
# 4    Niemcy    Peacock      2003-07-11         10252  3597.90
# ..      ...        ...             ...           ...      ...
# 794  Polska       King      2005-04-30         11048   525.00
# 795  Niemcy  Leverling      2005-05-01         11052  1332.00
# 796  Niemcy     Fuller      2005-04-29         11053  3055.00
# 797  Niemcy   Callahan      2005-05-01         11056  3740.00
# 798  Niemcy  Leverling      2005-05-01         11057    45.00
#
# [799 rows x 5 columns]

# %%
df_zamowienia_pl = df_zamowienia[df_zamowienia['Kraj']  == 'Polska']
df_zamowienia_pl
# Out:
#        Kraj Sprzedawca Data zamowienia  idZamowienia    Utarg
# 0    Polska   Kowalski      2003-07-16         10248   440.00
# 1    Polska   Sowiński      2003-07-10         10249  1863.40
# 6    Polska   Kowalski      2003-07-23         10254   556.62
# 7    Polska      Dudek      2003-07-15         10255  2490.50
# 15   Polska      Dudek      2003-07-31         10263  1873.80
# ..      ...        ...             ...           ...      ...
# 782  Polska       King      2005-04-23         11033  3232.80
# 786  Polska       King      2005-04-27         11037    60.00
# 790  Polska   Kowalski      2005-04-29         11043   210.00
# 793  Polska       King      2005-05-01         11047   817.87
# 794  Polska       King      2005-04-30         11048   525.00
#
# [215 rows x 5 columns]

# %%
sprzedawcy = df_zamowienia_pl.groupby('Sprzedawca').agg({'Utarg': 'sum'}).sort_values(by='Utarg', ascending=False)
sprzedawcy
# Out:
#                 Utarg
# Sprzedawca
# King        116962.99
# Dudek        75048.04
# Sowiński     72527.63
# Kowalski     68792.25

# %%
fig = px.funnel(sprzedawcy, x=sprzedawcy.index, y='Utarg')
fig.show()
# Out:
# <div>                            <div id="b1eee19f-3826-459c-997e-ab44dd2ac508" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1eee19f-3826-459c-997e-ab44dd2ac508")) {                    Plotly.newPlot(                        "b1eee19f-3826-459c-997e-ab44dd2ac508",                        [{"hovertemplate":"Sprzedawca=%{x}<br>Utarg=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","orientation":"v","showlegend":false,"x":["King","Dudek","Sowi\u0144ski","Kowalski"],"xaxis":"x","y":[116962.99,75048.04,72527.63,68792.25],"yaxis":"y","type":"funnel"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"line":{"color":"#283442"}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinew ...

# %% [markdown]
# ### Bazując na przykładzie w podrozdziale 1.3, stwórz wykres konturowanej mapy ciepła z podrozdziału https://plotly.com/python/2d-histogram-contour/ z dokumentacji biblioteki plotly.

# %%
fig = px.density_contour(df_zamowienia, x='Utarg', y='Sprzedawca')
fig.update_traces(contours_coloring='fill', contours_showlabels = True)
fig.show()
# Out:
# <div>                            <div id="5ab253e0-28a9-4c28-8668-43dd2fe5fabd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ab253e0-28a9-4c28-8668-43dd2fe5fabd")) {                    Plotly.newPlot(                        "5ab253e0-28a9-4c28-8668-43dd2fe5fabd",                        [{"contours":{"coloring":"fill","showlabels":true},"hovertemplate":"Utarg=%{x}<br>Sprzedawca=%{y}<br>count=%{z}<extra></extra>","legendgroup":"","line":{"color":"#636efa"},"name":"","showlegend":false,"x":[440.0,1863.4,1552.6,654.06,3597.9,1444.8,556.62,2490.5,517.8,1119.9,1614.88,100.8,1504.65,448.0,584.0,1873.8,695.62,1176.0,346.56,3536.6,1101.2,642.2,1376.0,48.0,1456.0,2037.28,538.6,291.84,420.0,1200.8,1488.8,351.0,613.2,86.5,155.4,1414.8,1170.37,1743.36,3016.0,819.0,80.1,479.4,2169.0,497.52,1296.0,848.7,1887.6,121.6,1050.6,1420.0,2645.0,349.5,608.0,755.0,2708.8,1117.8,954.4,3741.3,498.5,424.0,88.8,1762.0,336.0,268.8,1614.8,182.4,2094.3,516.8,2835.0,288.0,240.4,1191.2,516.0,144.0,112.0,164.4,5275.71,1497.0,982.0,1810.0,1168.0,4578.43,1649.0,88.5,1786.88,877.2,144.8,2036.16,285.12,2467.0,934.5,3354.0,2436.18,352.6,1840.64,1584.0,2296.0,2924.8,1618.88,814.42,363.6,141.6,642.06,5398.72,136.3,8593.28,568.8,480.0,1106.4,1167.68,429.4,3471.68,7390.2,2046.24,1549.6,447.2,950.0,403.2,136.0,834.2,1689.78,2390.4,1117.6,72.96,9210.9,1366.4,459.0,338.0,399.0,863.6,103.2,863.28,1313.82,112.0,2900.0,899.0,2222.4,691.2,166.0,1058.4,1228.8,1832.8,2090.88,86.4,1440.0,2556.95,442.0,2122.92,1903.8,716.72,2505.6,1765.6,3063.0,3868.6,2713.5,855.01,1591.25,400.0,1830.78,1194.0,1622.4,319.2,802.0,966.8,334.8,2123.2,224.83,102.4,720.0,11188.4,1814.8,2097.6,1707.84,1194.27,49.8,1020.0,9194.56,360.0,338.2,651.0,192.0,1441.37,4899.2,1892.25,485.0,851.2,321.12,631.6,1994.52,393.0,454.0,1078.0,4924.13,1755.0,1792.0,517.44,1031.7,174.9,246.24,914.4,443.4,1838.2,425.12,3849.66,2018.5,407.7,331.2,2684.0,557.6,1584.0,3891.0,1659.2,176.1,1538.7,156.0,713.3,1609.28,2518.0,216.0,235.2,717.6,956.67,1820.8,1328.0,1036.8,230.4,1249.1,1505.18,180.48,558.0,471.2,10495.6,756.0,1472.0,147.0,668.8,386.2,1584.0,1272.0,889.7,1512.0,439.2,3163.2,259.5,851.2,608.4,912.0,278.0,190.0,1380.6,575.0,1412.0,523.26,149.0,816.3,2048.5,1388.5,147.9,415.8,749.06,240.0,136.8,4707.54,2550.0,525.3,1942.0,8623.45,9921.3,2381.05,352.0,4150.05,2314.2,200.0,225.5,2318.24,2444.31,3192.65,818.4,1151.4,1503.0,392.2,946.0,4180.0,110.0,796.35,2222.2,465.7,1940.85,1645.0,1823.8,139.8,355.5,10191.7,1946.52,469.11,1504.5,417.2,210.0,2812.0,1792.8,240.1,3554.27,683.3,1677.3,880.5,1546.3,1728.52,2944.4,835.2,1152.5,2142.9,520.41,1072.42,2844.5,488.7,965.0,1234.05,639.9,1761.0,2519.0,155.0,890.0,2465.25,550.59,1501.08,2082.0,764.3,2147.4,838.45,569.0,477.0,317.75,1013.74,310.0,330.0,2237.5,593.75,142.5,23.8,807.38,3120.0,72.0,1101.0,812.5,516.46,1994.4,565.5,4725.0,1180.88,718.08,2388.5,493.0,479.8,2285.0,48.75,1483.0,230.85,4109.69,1130.4,6475.4,1064.0,424.0,299.25,808.0,6375.0,353.2,464.0,120.0,4806.99,1402.5,2697.5,1260.0,57.5,758.5,560.0,1336.95,1393.24,479.75,1503.6,1185.75,450.0,2775.05,903.6,55.8,589.0,5510.59,4985.5,1326.22,629.5,2761.94,2720.05,500.0,708.75,2054.0,696.0,814.5,1371.8,1535.0,1446.0,636.0,372.37,1434.0,1779.2,397.8,318.84,1083.15,601.83,154.4,604.21,4371.6,4464.6,1227.02,1701.0,562.6,125.0,1930.4,1288.39,1295.0,4666.94,1536.8,625.27,570.0,2301.75,920.1,3815.25,412.35,45.0,1423.0,534.85,813.36,5256.5,660.0,1261.88,1287.4,375.5,63.0,1768.0,801.1,1404.45,4960.9,3160.6,472.5,862.5,10164.8,878.0,2071.2,4825.0,642.0,996.0,805.43,3436.45,114.0,1638.4,2864.5,330.0,2545.0,595.5,378.0,1893.0,1641.0,180.4,3424.0,93.5,4451.7,1233.48,2827.9,2205.75,1296.0,706.0,1270.75,3463.0,844.25,550.0,923.87,1570.0,468.45,638.5,287.8,655.0,1624.5,1296.75,1850.0,484.25,1890.5,360.0, ...

# %% [markdown]
# ### Wykorzystując wykres typu icycle (https://plotly.com/python/icicle-charts/) wygeneruj wykres dla datasetu Fifa22 z użyciem kolumn Name, Nationality, Club, Value. Przed wyświetleniem wykresu należy dokonać preprocessingu danych:

# %%
df_fifa = pd.read_csv('data/FIFA22_official_data.csv')
df_fifa = df_fifa[['Name', 'Nationality', 'Club', 'Value']]
df_fifa
# Out:
#                   Name Nationality                   Club    Value
# 0      Bruno Fernandes    Portugal      Manchester United  €107.5M
# 1          L. Goretzka     Germany      FC Bayern München     €93M
# 2            L. Suárez     Uruguay     Atlético de Madrid   €44.5M
# 3         K. De Bruyne     Belgium        Manchester City  €125.5M
# 4             M. Acuña   Argentina             Sevilla FC     €37M
# ...                ...         ...                    ...      ...
# 16705    18 L. Clayton     England        Cheltenham Town    €100K
# 16706         �. Dobre     Romania  FC Academica Clinceni    €180K
# 16707   21 Xue Qinghao    China PR    Shanghai Shenhua FC    €100K
# 16708        A. Shaikh       India     ATK Mohun Bagan FC    €110K
# 16709    07 A. Censori       Italy                 Arezzo       €0
#
# [16710 rows x 4 columns]

# %% [markdown]
# #### dane należy ograniczyć tylko do dwóch krajów: Polska i Hiszpania

# %%
df_fifa_pl_sp = df_fifa[(df_fifa['Nationality'] == 'Poland') | (df_fifa['Nationality'] == 'Spain')]
df_fifa_pl_sp
# Out:
#                        Name Nationality                   Club   Value
# 11          Marcos Llorente       Spain     Atlético de Madrid    €88M
# 12             Sergio Ramos       Spain    Paris Saint-Germain    €24M
# 14                   Merino       Spain          Real Sociedad    €50M
# 20                     Koke       Spain     Atlético de Madrid  €52.5M
# 32               Jordi Alba       Spain           FC Barcelona    €47M
# ...                     ...         ...                    ...     ...
# 16665         S. Westerveld       Spain             AZ Alkmaar   €400K
# 16667        D. Szczepaniak      Poland            Wrexham AFC   €180K
# 16673  M. Pérez Hintermeier       Spain  FC Würzburger Kickers    €90K
# 16675          K. Trelowski      Poland      Raków Częstochowa   €350K
# 16699       F. Chalupniczak      Poland          Sutton United   €120K
#
# [1412 rows x 4 columns]

# %% [markdown]
# #### w kolumnie Value należy dokonać oczyszczenia wartości z symbolu waluty oraz konwertować na typ float a wcześnie uzupełnić brakujące wartości zerami

# %%
df_fifa_pl_sp['Value'] = df_fifa_pl_sp['Value'].str.replace(r'\D+', '', regex=True).astype('float')
df_fifa_pl_sp
# Out:
# C:\Users\barjan\AppData\Local\Temp\ipykernel_11768\283058765.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Name Nationality                   Club  Value
# 11          Marcos Llorente       Spain     Atlético de Madrid   88.0
# 12             Sergio Ramos       Spain    Paris Saint-Germain   24.0
# 14                   Merino       Spain          Real Sociedad   50.0
# 20                     Koke       Spain     Atlético de Madrid  525.0
# 32               Jordi Alba       Spain           FC Barcelona   47.0
# ...                     ...         ...                    ...    ...
# 16665         S. Westerveld       Spain             AZ Alkmaar  400.0
# 16667        D. Szczepaniak      Poland            Wrexham AFC  180.0
# 16673  M. Pérez Hintermeier       Spain  FC Würzburger Kickers   90.0
# 16675          K. Trelowski      Poland      Raków Częstochowa  350.0
# 16699       F. Chalupniczak      Poland          Sutton United  120.0
#
# [1412 rows x 4 columns]

# %%
df_fifa_pl_sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1412 entries, 11 to 16699
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         1412 non-null   object
#  1   Nationality  1412 non-null   object
#  2   Club         1409 non-null   object
#  3   Value        1412 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 55.2+ KB

# %% [markdown]
# #### w kolumnie Club również mogą występować puste wartości, usuń je z dataframe użytego do wyświetlenia na wykresie (ale nie z oryginału).

# %%
df_fifa_pl_sp_nonull = df_fifa_pl_sp.dropna()
df_fifa_pl_sp_nonull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1409 entries, 11 to 16699
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         1409 non-null   object
#  1   Nationality  1409 non-null   object
#  2   Club         1409 non-null   object
#  3   Value        1409 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 55.0+ KB

# %%
fig = px.icicle(df_fifa_pl_sp_nonull, path=[px.Constant('all'), 'Nationality', 'Club', 'Name'], values='Value')
fig.show()
# Out:
# C:\Users\barjan\anaconda3\envs\WD\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\barjan\anaconda3\envs\WD\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\barjan\anaconda3\envs\WD\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# C:\Users\barjan\anaconda3\envs\WD\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <div>                            <div id="0592c8b1-5483-42a2-ae0e-9f7e4971ba3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0592c8b1-5483-42a2-ae0e-9f7e4971ba3b")) {                    Plotly.newPlot(                        "0592c8b1-5483-42a2-ae0e-9f7e4971ba3b",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Value=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["all/Spain/Real Betis Balompi\u00e9/07\u00a0Romero","all/Spain/Elche CF/09\u00a0Miguel","all/Spain/C\u00e1diz CF/10\u00a0Trist\u00e1n","all/Spain/Be\u015fikta\u015f JK/11\u00a0Guti","all/Poland/Real Madrid CF/11\u00a0J. Dudek","all/Spain/FC Schalke 04/12\u00a0Ra\u00fal","all/Spain/Brighton & Hove Albion/13\u00a0Vicente","all/Spain/FC Barcelona/14\u00a0Pinto","all/Spain/FC Barcelona/14\u00a0Puyol","all/Poland/Jagiellonia Bia\u0142ystok/15\u00a0A. Waszkiewicz","all/Spain/RCD Mallorca/15\u00a0Albert Riera","all/Spain/Lierse SK/15\u00a0Capdevila","all/Spain/Real Sociedad/15\u00a0Iker Hern\u00e1ndez","all/Spain/FC Barcelona/15\u00a0Xavi","all/Spain/Uni\u00f3n Deportiva Almer\u00eda/16\u00a0Carlos Cu\u00e9llar","all/Spain/Deportivo Alav\u00e9s/16\u00a0Dani Estrada","all/Spain/Central Coast Mariners/16\u00a0Luis Garc\u00eda","all/Spain/Arsenal/16\u00a0Mikel Arteta","all/Spain/Uni\u00f3n Deportiva Almer\u00eda/16\u00a0Soriano","all/Spain/Uni\u00f3n Deportiva Las Palmas/16\u00a0Valer\u00f3n","all/Spain/Gimn\u00e0stic de Tarragona/16\u00a0Xisco Mu\u00f1oz","all/Spain/CD Tondela/16\u00a0Zubikarai","all/Spain/Real Valladolid CF/16\u00a0\u00d3scar","all/Spain/Athletic Club de Bilbao/17\u00a0Agirrezabala","all/Spain/West Ham United/17\u00a0Arbeloa","all/Spain/C\u00e1diz CF/17\u00a0Dani G\u00fciza","all/Spain/SD Huesca/17\u00a0David L\u00f3pez","all/Spain/Rayo Vallecano/17\u00a0Jordi G\u00f3mez","all/Spain/Real Zaragoza/17\u00a0Jos\u00e9 Enrique","all/Spain/Gimn\u00e0stic de Tarragona/17\u00a0Lopo","all/Spain/Real Oviedo/17\u00a0Michu","all/Spain/Levante Uni\u00f3n Deportiva/17\u00a0Natxo Insa","all/Spain/Real Valladolid CF/17\u00a0Pau Torres","all/Spain/Middlesbrough/17\u00a0Victor Vald\u00e9s","all/Spain/FC Bayern M\u00fcnchen/17\u00a0Xabi Alonso","all/Spain/Novara Calcio/18\u00a0Andrea Orlandi","all/Spain/Dundee FC/18\u00a0Aurtenetxe","all/Poland/Real Zaragoza/18\u00a0C. Wilk","all/Spain/SD Eibar/18\u00a0Cristian","all/Poland/TSG Hoffenheim/18\u00a0E. Pola\u0144ski","all/Spain/Deportivo de La Coru\u00f1a/18\u00a0Fernando Navarro","all/Spain/Atl\u00e9tico de Madrid/18\u00a0Gabi","all/Poland/Sandecja Nowy S\u0105cz/18\u00a0J. Straus","all/Spain/CA Osasuna/18\u00a0Javi Fla\u00f1o","all/Spain/Athletic Club de Bilbao/18\u00a0Kike Sola","all/Spain/C\u00e1diz CF/18\u00a0Moha","all/Spain/Athletic Club de Bilbao/18\u00a0Saborit","all/Spain/CD Legan\u00e9s/18\u00a0Sergio Arribas","all/Spain/Real Sociedad/18\u00a0To\u00f1o Ram\u00edrez","all/Spain/Real Sociedad/18\u00a0Xabi Prieto","all/Spain/Real Sociedad/19\u00a0Agirretxe","all/Spain/Granada CF/19\u00a0Baena","all/Spain/Albacete BP/19\u00a0Borja Herrera","all/Spain/Real Oviedo/19\u00a0Carlos Mart\u00ednez","all/Spain/Gimn\u00e0stic de Tarragona/19\u00a0Cot\u00e1n","all/Spain/Sint-Truidense VV/19\u00a0Cristian Ceballos","all/Poland/GFC Ajaccio/19\u00a0D. Perquis","all/Spain/Uni\u00f3n Deportiva Las Palmas/19\u00a0David Garc\u00eda","all/Spain/Real Zaragoza/19\u00a0Diego Aguirre","all/Spain/Extremadura UD/19\u00a0Diego Capel","all/Spain/Rayo Vallecano/19\u00a0Elustondo","all/Spain/Sagan Tosu/19\u00a0Fernando Torres","all/Spain/CF Rayo Majadahonda/19\u00a0Gal\u00e1n","all/Spain/Gimn\u00e0stic de Tarragona/19\u00a0Imanol Garc\u00eda","all/Spain/Gimn\u00e0stic de Tarragona/19\u00a0Isaac Becerra","all/Spain/Gimn\u00e ...
