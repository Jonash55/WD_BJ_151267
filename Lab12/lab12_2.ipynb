# %%
library("ggplot2")
library("readxl")
transport <- read_excel("data/Transport_Przewozy ładunków.xlsx")
transport <- t(transport)
transport
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#       [,1] [,2]              [,3]                  [,4]
# nazwa Rok  Przewozy_ladunkow transportem_kolejowym normalnotorowym
# 1     1950 342 066 536       160 365 000           150 321 000
# 2     1951 408 744 072       176 311 000           165 563 000
# 3     1952 448 305 871       187 183 000           175 814 000
# 4     1953 524 328 332       211 377 000           199 347 000
# 5     1954 554 813 010       221 939 000           209 560 000
# 6     1955 581 218 088       236 422 000           223 673 000
# 7     1956 618 970 657       239 199 000           226 523 000
# 8     1957 615 962 058       248 940 000           236 246 000
# 9     1958 636 361 217       249 947 000           237 468 000
# 10    1959 671 707 402       264 551 000           252 157 000
# 11    1960 719 867 318       286 882 000           273 664 000
# ...
